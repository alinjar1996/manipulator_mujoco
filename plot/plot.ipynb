# %%
# 1. Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

import os

print("Current Path", os.getcwd())
# Out:
# Current Path /home/alinjar/manipulator/manipulator_mujoco/plot

# %%
# 2. Load the CSV file
# Replace 'your_file.csv' with the path to your CSV file
folder = 'custom_data'
csv_path_thetadot = f'../{folder}/thetadot.csv'
csv_path_theta = f'../{folder}/theta.csv'
df_thetadot = pd.read_csv(csv_path_thetadot)
df_theta = pd.read_csv(csv_path_theta)

# %%
# 3. Display the first few rows of the dataset
#df.head()

print(df_theta.shape)
print(df_theta.shape[0])

print(df_thetadot.shape)
print(df_thetadot.shape[0])
# Out:
# (150, 6)
# 150
# (150, 6)
# 150

# %%
# 4. Plot the data
# Replace 'column_x' and 'column_y' with actual column names from your CSV

import numpy as np

x_col = np.linspace(0, df_theta.shape[0]-1, df_theta.shape[0])
y_col = df_theta.columns[:]

plt.figure(figsize=(10, 6))
# plt.plot(x_col, df_theta[y_col], marker='o', linestyle='-')
plt.plot(df_theta[y_col])
# plt.title( 'Thetadot vs Time')
# plt.xlabel('Time')
# plt.ylabel('Thetadot')
plt.grid(True)
plt.show()

# %%
# 5. Plot the data
# Replace 'column_x' and 'column_y' with actual column names from your CSV

import numpy as np

x_col = np.linspace(0, df_thetadot.shape[0]-1, df_thetadot.shape[0])
y_col = df_thetadot.columns[:]

plt.figure(figsize=(10, 6))
# plt.plot(x_col, df_thetadot[y_col], marker='o', linestyle='-')
plt.plot(df_thetadot[y_col])
# plt.title( 'Thetadot vs Time')
# plt.xlabel('Time')
# plt.ylabel('Thetadot')
plt.grid(True)
plt.show()
